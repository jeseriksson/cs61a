# %%
import math

def a_plus_abs_b(a, b):
    """Return a+abs(b), but without calling abs.

    >>> a_plus_abs_b(2, 3)
    5
    >>> a_plus_abs_b(2, -3)
    5
    >>> # a check that you didn't change the return statement!
    >>> import inspect, re
    >>> re.findall(r'^\s*(return .*)', inspect.getsource(a_plus_abs_b), re.M)
    ['return h(a, b)']
    """
    if b >= 0:
        h = a + b
    else:
        h = a + math.sqrt(b**2)
    return h

# %%
a_plus_abs_b(1, -2)
# Out:
# 3.0

# %%
def two_of_three(x, y, z):
    """Return a*a + b*b, where a and b are the two smallest members of the
    positive numbers x, y, and z.

    >>> two_of_three(1, 2, 3)
    5
    >>> two_of_three(5, 3, 1)
    10
    >>> two_of_three(10, 2, 8)
    68
    >>> two_of_three(5, 5, 5)
    50
    >>> # check that your code consists of nothing but an expression (this docstring)
    >>> # a return statement
    >>> import inspect, ast
    >>> [type(x).__name__ for x in ast.parse(inspect.getsource(two_of_three)).body[0].body]
    ['Expr', 'Return']
    """
    p = [x, y, z]
    p.remove(max(x, y, z)
    return [a**2 + b**2 for a, b in p]

def sums_of_two(x, y, z):
  a = min(x, y, z)
  array = [x, y, z]
  for a in array: 
    array.remove(a)
  b = min(array)
  return a+b
# Out:
#   File "<ipython-input-54-01aaffa8e726>", line 21
#     return [(a**2 + b**2) for a, b in p]
#          ^
# SyntaxError: invalid syntax

# %%
two_of_three(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-81b1830e1046> in <module>()
# ----> 1 two_of_three(1, 2, 3)
#
# <ipython-input-51-a0aa8eae9557> in two_of_three(x, y, z)
#      18     """
#      19     a = [x, y, z]
# ---> 20     return [a**2 + b**2 for a, b in [a.remove(max(x, y, z))]]
#      21
#      22 def sums_of_two(x, y, z):
#
# <ipython-input-51-a0aa8eae9557> in <listcomp>(.0)
#      18     """
#      19     a = [x, y, z]
# ---> 20     return [a**2 + b**2 for a, b in [a.remove(max(x, y, z))]]
#      21
#      22 def sums_of_two(x, y, z):
#
# TypeError: 'NoneType' object is not iterable

# %%
def we(x, y, z):
  a = [x, y, z]
  a.remove(max(x, y, z))
  return a

print(we(1, 2, 3))
# Out:
# [1, 2]

# %%
def largest_factor(x):
    """Return the largest factor of x that is smaller than x.

    >>> largest_factor(15) # factors are 1, 3, 5
    5
    >>> largest_factor(80) # factors are 1, 2, 4, 5, 8, 10, 16, 20, 40
    40
    >>> largest_factor(13) # factor is 1 since 13 is prime
    1
    """
    "*** YOUR CODE HERE ***"
    factors = []
    for i in range(1, int(x*0.5)+1):
      if x % i == 0:
        factors.append(i)
    return max(factors)

# %%
print(largest_factor(15))
# Out:
# 5

# %%
def if_function(condition, true_result, false_result):
    """Return true_result if condition is a true value, and
    false_result otherwise.

    >>> if_function(True, 2, 3)
    2
    >>> if_function(False, 2, 3)
    3
    >>> if_function(3==2, 3+2, 3-2)
    1
    >>> if_function(3>2, 3+2, 3-2)
    5
    """
    if condition:
        return true_result
    else:
        return false_result

def with_if_statement():
    """
    >>> result = with_if_statement()
    47
    >>> print(result)
    None
    """
    if cond():
        return true_func()
    else:
        return false_func()

def with_if_function():
    """
    >>> result = with_if_function()
    42
    47
    >>> print(result)
    None
    """
    return if_function(cond(), true_func(), false_func())

def cond():
    "*** YOUR CODE HERE ***"
    return True

def true_func():
    "*** YOUR CODE HERE ***"
    return 47

def false_func():
    "*** YOUR CODE HERE ***"
    print('47', '42')
    return 1/0

# %%
print(with_if_statement())
print(with_if_function())
# Out:
# 47
# 47 42
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-ebaf57ef9723> in <module>()
#       1 print(with_if_statement())
# ----> 2 print(with_if_function())
#
# <ipython-input-13-6d76b3a40553> in with_if_function()
#      37     None
#      38     """
# ---> 39     return if_function(cond(), true_func(), false_func())
#      40
#      41 def cond():
#
# <ipython-input-13-6d76b3a40553> in false_func()
#      50     "*** YOUR CODE HERE ***"
#      51     print('47', '42')
# ---> 52     return 1/0
#
# ZeroDivisionError: division by zero

# %%
def hailstone(x):
    """Print the hailstone sequence starting at x and return its
    length.

    >>> a = hailstone(10)
    10
    5
    16
    8
    4
    2
    1
    >>> a
    7
    """
    "*** YOUR CODE HERE ***"
    counter = 0
    while x != 1:
      if x % 2 == 0:
        x = x / 2
        print(x)
        counter += 1
      else:
        x = x * 3 + 1
        print(x)
        counter += 1
    return print('The Hailstone length is: {0}'.format(counter))

# %%
hailstone(27)
# Out:
# 82
# 41.0
# 124.0
# 62.0
# 31.0
# 94.0
# 47.0
# 142.0
# 71.0
# 214.0
# 107.0
# 322.0
# 161.0
# 484.0
# 242.0
# 121.0
# 364.0
# 182.0
# 91.0
# 274.0
# 137.0
# 412.0
# 206.0
# 103.0
# 310.0
# 155.0
# 466.0
# 233.0
# 700.0
# 350.0
# 175.0
# 526.0
# 263.0
# 790.0
# 395.0
# 1186.0
# 593.0
# 1780.0
# 890.0
# 445.0
# 1336.0
# 668.0
# 334.0
# 167.0
# 502.0
# 251.0
# 754.0
# 377.0
# 1132.0
# 566.0
# 283.0
# 850.0
# 425.0
# 1276.0
# 638.0
# 319.0
# 958.0
# 479.0
# 1438.0
# 719.0
# 2158.0
# 1079.0
# 3238.0
# 1619.0
# 4858.0
# 2429.0
# 7288.0
# 3644.0
# 1822.0
# 911.0
# 2734.0
# 1367.0
# 4102.0
# 2051.0
# 6154.0
# 3077.0
# 9232.0
# 4616.0
# 2308.0
# 1154.0
# 577.0
# 1732.0
# 866.0
# 433.0
# 1300.0
# 650.0
# 325.0
# 976.0
# 488.0
# 244.0
# 122.0
# 61.0
# 184.0
# 92.0
# 46.0
# 23.0
# 70.0
# 35.0
# 106.0
# 53.0
# 160.0
# 80.0
# 40.0
# 20.0
# 10.0
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0
# The Hailstone length is: 111
